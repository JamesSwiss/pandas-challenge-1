# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df_client = pd.read_csv('Resources/client_dataset.csv')
df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number', 'line_subtotal'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number  line_subtotal
# count  54639.000000  54639.000000  5.463900e+04  54639.000000   5.463900e+04
# mean      99.446073      5.004116  5.702646e+02      2.979667   7.710286e+04
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
df.info
# Out:
# <bound method DataFrame.info of            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
# ...

# %%
# What three item categories had the most entries?
#df['category'].value_counts()
df['category'].value_counts().head(3)
# Out:
# consumables    23538
# furniture      11915
# software        8400
# Name: category, dtype: int64

# %%
# For the category with the most entries,
# which subcategory had the most entries?
df['subcategory'].value_counts().head(1)
# Out:
# bathroom supplies    6424
# Name: subcategory, dtype: int64

# %%
# Which five clients had the most entries in the data?
df['client_id'].value_counts().head(5)
# Out:
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: client_id, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
client_id = ['33615', '66037', '46820', '38378', '24741']
print (client_id)
# Out:
# ['33615', '66037', '46820', '38378', '24741']

# %%
# How many total units (the qty column) did the
# client with the most entries order?

df_client[df_client['client_id'] == 33615]['qty'].sum()

print(total_units_client_id)
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the
# subtotal for each line using the unit_price
# and the qty
df['line_subtotal'] = df['unit_price'] * df['qty']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.


df_client['shipping_price'] = df_client['unit_weight'].apply(lambda x: 7 if x > 50 else 10) * df_client['qty']

df_client.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%

# Create a column for total price including sales tax.



df_client['subtotal'] = df_client['unit_price'] * df_client['qty']


df_client['shipping_price'] = df_client['unit_weight'].apply(lambda x: 7 if x > 50 else 10) * df_client['qty']


df_client['total_price'] = (df_client['subtotal'] + df_client['shipping_price']) * (1 + 0.0925)


df_client.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...     category         subcategory unit_price  \
# ...

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).

df_client['line_cost'] = (df_client['unit_cost'] * df_client['qty']) + df_client['shipping_price']

# Display the first few rows to verify the new column
df_client[['unit_cost', 'qty', 'shipping_price', 'line_cost']].head()
# Out:
#    unit_cost  qty  shipping_price  line_cost
# 0     762.71  105            1050   81134.55
# 1      15.09   21             210     526.89
# 2       7.86   39             390     696.54
# 3      24.85   29             290    1010.65
# 4     108.17   20             200    2363.40

# %%
# Create a column for the profit of
# each line using line cost and line price

df_client['line_profit'] = df_client['subtotal'] - df_client['line_cost']


df_client[['subtotal', 'line_cost', 'line_profit']].head()
# Out:
#     subtotal  line_cost  line_profit
# 0  115164.00   81134.55     34029.45
# 1     523.95     526.89        -2.94
# 2     527.28     696.54      -169.26
# 3    1056.18    1010.65        45.53
# 4    3902.00    2363.40      1538.60

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.

total_spending_top_clients_ = df_client[df_client['client_id'].isin(top_clients_by_qty)].groupby('client_id')['total_price'].sum()

total_spending_top_clients_
# Out:
# client_id
# 30143    3.275942e+07
# 77354    5.145733e+07
# 78965    6.941527e+08
# 85931    2.333984e+08
# 86721    1.220184e+08
# Name: total_price, dtype: float64

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.



# Calculate the total units purchased, total shipping price, total revenue, and total profit for the top 5 clients
top_clients_summary = df_client.groupby('client_id').agg(
    total_units_purchased=('qty', 'sum'),
    total_shipping_price=('shipping_price', 'sum'),
    total_revenue=('subtotal', 'sum'),
    total_profit=('line_profit', 'sum')
).nlargest(5, 'total_profit')  # Sorting by total profit

top_clients_summary
# Out:
#            total_units_purchased  total_shipping_price  total_revenue  \
# client_id
# 78965                    4033302              40333020   5.950470e+08
# 85931                     644423               6444230   2.071928e+08
# 24741                     239862               2398620   7.017689e+07
# 38473                     402770               4027700   1.636205e+08
# 86721                    1010426              10104260   1.015831e+08
#
#            total_profit
# client_id
# 78965      1.514840e+08
# 85931      8.274823e+07
# 24741      2.721581e+07
# 38473      2.378296e+07
# 86721      1.752295e+07

# %%
# Format the data and rename the columns
# to names suitable for presentation.
# Currency should be in millions of dollars.

top_clients_summary['total_units_purchased'] = top_clients_summary['total_units_purchased']
top_clients_summary['total_shipping_price'] = top_clients_summary['total_shipping_price'] / 1e6
top_clients_summary['total_revenue'] = top_clients_summary['total_revenue'] / 1e6
top_clients_summary['total_profit'] = top_clients_summary['total_profit'] / 1e6

top_clients_summary.columns = [
    'Total Units Purchased',
    'Total Shipping Price (M$)',
    'Total Revenue (M$)',
    'Total Profit (M$)'
]

top_clients_summary.reset_index(inplace=True)
top_clients_summary
# Out:
#    client_id  Total Units Purchased  Total Shipping Price (M$)  \
# 0      78965                4033302                   40.33302
# 1      85931                 644423                    6.44423
# 2      24741                 239862                    2.39862
# 3      38473                 402770                    4.02770
# 4      86721                1010426                   10.10426
#
#    Total Revenue (M$)  Total Profit (M$)
# 0          595.047042         151.483951
# 1          207.192784          82.748231
# 2           70.176885          27.215814
# 3          163.620504          23.782962
# 4          101.583080          17.522946

# %%
# Sort the updated data by "Total Profit" form highest to lowest

top_clients_summary_sorted = top_clients_summary.sort_values(by='Total Profit (M$)', ascending=False)

top_clients_summary_sorted
# Out:
#    client_id  Total Units Purchased  Total Shipping Price (M$)  \
# 0      78965                4033302                   40.33302
# 1      85931                 644423                    6.44423
# 2      24741                 239862                    2.39862
# 3      38473                 402770                    4.02770
# 4      86721                1010426                   10.10426
#
#    Total Revenue (M$)  Total Profit (M$)
# 0          595.047042         151.483951
# 1          207.192784          82.748231
# 2           70.176885          27.215814
# 3          163.620504          23.782962
# 4          101.583080          17.522946
